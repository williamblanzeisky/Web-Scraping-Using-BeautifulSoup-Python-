# %% [markdown]
# # Web Scraping using Beautiful Soup
#
# #### Author: William Blanzeisky: github.com/williamblanzeisky
#
# This project is to scrape Minnesota State University, Mankato catalog data. The link to the catalog is https://mankato.mnsu.edu/academics/academic-catalog/undergraduate/computer-information-technology/computer-information-technology-bs/. The tasks go as follows:
# - import all the libraries needed
# - assign the variable "url" to the specific URL we're trying to scrape
# - Inspect the website and find what data you're trying to scrape
# - Data cleaning
# - Convert data into pandas dataframe (so that you can convert it into .csv file.
#
# This code is written in Python 3.

# %%
# import all the libraries needed
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
# assign url to the link we're trying to scrape
url = 'https://mankato.mnsu.edu/academics/academic-catalog/undergraduate/computer-information-technology/computer-information-technology-bs/'
response = requests.get(url)

# %%
# test connection - successful!
response
# Out:
# <Response [200]>

# %%
# initialize beautiful soup 
soup = BeautifulSoup(response.text, "html.parser")

# %%
# After inspecting the website, we see that the data we want is in <span> code. Therefore, we tell beautifulSoup to 
# scrape every <span> code in the website.
soup.findAll('span')
# Out:
# [<span class="caret"></span>,
#  <span class="sr-only">Search</span>,
#  <span class="btn-hamburger__text">Open Menu</span>,
#  <span class="btn-hamburger__wrapper">
#  <span class="btn-hamburger__bun"></span>
#  <span class="btn-hamburger__bun"></span>
#  <span class="btn-hamburger__bun"></span>
#  </span>,
#  <span class="btn-hamburger__bun"></span>,
#  <span class="btn-hamburger__bun"></span>,
#  <span class="btn-hamburger__bun"></span>,
#  <span class="input-group-btn">
#  <button class="btn btn-default search-bar-btn" type="submit">Search</button>
#  </span>,
#  <span class="btn-hamburger__text">Close</span>,
#  <span class="caret"></span>,
#  <span class="caret"></span>,
#  <span><img alt="Harley Ries, Minnesota State Mankato student" height="166" src="/globalassets/globalassets/images/woit_160419_0013.jpg" style="float: left; margin-left: 10px; margin-right: 10px;" width="250">“Minnesota State Mankato supplies its students with countless valuable opportunities—whether it be starting a business with your Integrated Business Experience classmates in a low-risk environment, leading 30-40 new students as a Community Advisor during their transition to college, or joining a club or organization that presents critical values, beliefs, and support.”</img></span>,
#  <span class="caret"></span>,
#  <span class="caret"></span>,
#  <span class="caret"></span>,
#  <span class="markg5q6d43i6" data-markjs="true" data-ogab="" data-ogac="" data-ogsb="" data-ogsc="">Coronavirus</span>,
#  <span>ENG 101</span>,
#  <span>Composition</span>,
#  <span>4 credits</span>,
#  <span>none</span>,
#  <span>IT 202W</span>,
#  <span>Computers in Society</span>,
#  <span>4 credits</span>,
#  <span>none</span>,
#  <span>MATH 121</span>,
#  <span>Calculus I</span>,
#  <span>4 credits</span>,
#  <span>STAT 154</span>,
#  <span>Elementary Statistics</span>,
#  <span>4 credits</span>,
#  <span>CMST 100</span>,
#  <span>Fundamentals of Communication</span>,
#  <span>3 credits</span>,
#  <span>none</span>,
#  <span>CMST 102</span>,
#  <span>Public Speaking</span>,
#  <span>3 credits</span>,
#  <span>none</span>,
#  <span>CMST 312</span>,
#  <span>Professional Communication and Interviewing</span>,
#  <span>4 credits</span>,
#  <span>none</span>,
#  <span>ENG 271W</span>,
#  <span>Technical Communication</span>,
#  <span>4 credits</span>,
#  <span>IT 210</span>,
#  <span>Fundamentals of Programming</span>,
#  <span>4 credits</span>,
#  <span>IT 214</span>,
#  <span>Fundamentals of Software Development</span>,
#  <span>4 credits</span>,
#  <span>IT 310</span>,
#  <span>Data Structures &amp; Algorithms</span>,
#  <span>4 credits</span>,
#  <span>IT 320</span>,
#  <span>Machine Structures and Operating Systems</span>,
#  <span>4 credits</span>,
#  <span>IT 340</span>,
#  <span>Introduction to Database Systems</span>,
#  <span>4 credits</span>,
#  <span>IT 350</span>,
#  <span>Information Security</span>,
#  <span>4 credits</span>,
#  <span>IT 360</span>,
#  <span>Introduction to Networking</span>,
#  <span>4 credits</span>,
#  <span>IT 380</span>,
#  <span>Systems Analysis and Design</span>,
#  <span>4 credits</span>,
#  <span>IT 440</span>,
#  <span>Database Management Systems</span>,
#  <span>4 credits</span>,
#  <span>IT 497</span>,
#  <span>Internship</span>,
#  <span>1-12 credits</span>,
#  <span class="sr-only">Toggle menu</span>]

# %%
# initialize empty array as a temporary storage for the data we're trying to scrape
course_number = []
course_name = []
credit_hours = []
i = 0;

# %%
# initialize a while loop to go through all <span> data and extract the information we need
# print is used for debugging purposes

while (i <= (len(soup.findAll('span'))-3)):
    if str(soup.findAll('span')[i]).startswith("<span>") == True and str(soup.findAll('span')[i]).startswith("<span><img")== False and soup.findAll('span')[i].text != "none":
        print(i)
        courseNumber = soup.find_all("span")[i].text
        courseName = soup.find_all("span")[i+1].text
        creditHours = soup.find_all("span")[i+2].text
        course_number.append(courseNumber)
        course_name.append(courseName)
        credit_hours.append(creditHours)
        print(course_number)
        print(course_name)
        print(credit_hours)
        i = i+3
    else:
        i = i+1
# Out:
# 16
# ['ENG 101']
# ['Composition']
# ['4 credits']
# 20
# ['ENG 101', 'IT 202W']
# ['Composition', 'Computers in Society']
# ['4 credits', '4 credits']
# 24
# ['ENG 101', 'IT 202W', 'MATH 121']
# ['Composition', 'Computers in Society', 'Calculus I']
# ['4 credits', '4 credits', '4 credits']
# 27
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics']
# ['4 credits', '4 credits', '4 credits', '4 credits']
# 30
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits']
# 34
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits']
# 38
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits']
# 42
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits']
# 45
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits']
# 48
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 51
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 54
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 57
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320', 'IT 340']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems', 'Introduction to Database Systems']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 60
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320', 'IT 340', 'IT 350']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems', 'Introduction to Database Systems', 'Information Security']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 63
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320', 'IT 340', 'IT 350', 'IT 360']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems', 'Introduction to Database Systems', 'Information Security', 'Introduction to Networking']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 66
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320', 'IT 340', 'IT 350', 'IT 360', 'IT 380']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems', 'Introduction to Database Systems', 'Information Security', 'Introduction to Networking', 'Systems Analysis and Design']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 69
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320', 'IT 340', 'IT 350', 'IT 360', 'IT 380', 'IT 440']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems', 'Introduction to Database Systems', 'Information Security', 'Introduction to Networking', 'Systems Analysis and Design', 'Database Management Systems']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits']
# 72
# ['ENG 101', 'IT 202W', 'MATH 121', 'STAT 154', 'CMST 100', 'CMST 102', 'CMST 312', 'ENG 271W', 'IT 210', 'IT 214', 'IT 310', 'IT 320', 'IT 340', 'IT 350', 'IT 360', 'IT 380', 'IT 440', 'IT 497']
# ['Composition', 'Computers in Society', 'Calculus I', 'Elementary Statistics', 'Fundamentals of Communication', 'Public Speaking', 'Professional Communication and Interviewing', 'Technical Communication', 'Fundamentals of Programming', 'Fundamentals of Software Development', 'Data Structures & Algorithms', 'Machine Structures and Operating Systems', 'Introduction to Database Systems', 'Information Security', 'Introduction to Networking', 'Systems Analysis and Design', 'Database Management Systems', 'Internship']
# ['4 credits', '4 credits', '4 credits', '4 credits', '3 credits', '3 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '4 credits', '1-12 credits']

# %%
# convert the arrays into a dataframe with desired column names
catalog = pd.DataFrame({'Course Number':course_number, 'Course Name':course_name, 'Credit Hours':credit_hours})

# %%
# catalog dataframe
catalog
# Out:
#    Course Number                                  Course Name  Credit Hours
# 0        ENG 101                                  Composition     4 credits
# 1        IT 202W                         Computers in Society     4 credits
# 2       MATH 121                                   Calculus I     4 credits
# 3       STAT 154                        Elementary Statistics     4 credits
# 4       CMST 100                Fundamentals of Communication     3 credits
# 5       CMST 102                              Public Speaking     3 credits
# 6       CMST 312  Professional Communication and Interviewing     4 credits
# 7       ENG 271W                      Technical Communication     4 credits
# 8         IT 210                  Fundamentals of Programming     4 credits
# 9         IT 214         Fundamentals of Software Development     4 credits
# 10        IT 310                 Data Structures & Algorithms     4 credits
# 11        IT 320     Machine Structures and Operating Systems     4 credits
# 12        IT 340             Introduction to Database Systems     4 credits
# 13        IT 350                         Information Security     4 credits
# 14        IT 360                   Introduction to Networking     4 credits
# 15        IT 380                  Systems Analysis and Design     4 credits
# 16        IT 440                  Database Management Systems     4 credits
# 17        IT 497                                   Internship  1-12 credits
